# %% [markdown]
# # Exercise 7.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 7.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.2.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.2.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.2.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 7.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 7.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.4.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.4.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.4.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 7.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.5.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 7.5.2

# %% [markdown]
# ![image.png](attachment:image.png)
